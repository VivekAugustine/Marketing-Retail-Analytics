# %%
import numpy as np   
import pandas as pd    
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
sns.set(color_codes=True)

# %%
df = pd.read_csv('downloads/answer/Project/MRA Project - 2/dataset_group.csv')
df.head()
# Out:
#          Date  Order_id        Product
# 0  01-01-2018         1         yogurt
# 1  01-01-2018         1           pork
# 2  01-01-2018         1  sandwich bags
# 3  01-01-2018         1     lunch meat
# 4  01-01-2018         1   all- purpose

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20641 entries, 0 to 20640
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      20641 non-null  object
#  1   Order_id  20641 non-null  int64
#  2   Product   20641 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 483.9+ KB

# %%
df.describe().T
# Out:
#             count        mean         std  min    25%    50%    75%     max
# Order_id  20641.0  575.986289  328.557078  1.0  292.0  581.0  862.0  1139.0

# %%
plt.figure(figsize =(13,13))
sns.barplot(data =df,x ='Order_id',y ='Product')
# Out:
# <AxesSubplot:xlabel='Order_id', ylabel='Product'>

# %%
df1 = pd.read_csv('downloads/answer/Project/MRA Project - 2/MBA.csv')
df1.head()
# Out:
#     Support  Confidence      Lift Recommended_Product Recommended_with  \
# 0  0.080773    1.000000  2.600457            aluminum             <---
# 1  0.080773    0.968421  2.638832               foil,             <---
# 2  0.080773    1.000000  2.642691             laundry             <---
# 3  0.080773    0.968421  2.696899          detergent,             <---
# 4  0.080773    0.747967  1.290811            sandwich             <---
#
#               Recommended_Set
# 0       [foil,, yogurt,, ice]
# 1    [yogurt,, ice, aluminum]
# 2  [soap,, detergent,, pork,]
# 3     [laundry, soap,, pork,]
# 4     [all-, soap,, ketchup,]

# %%
df1.describe().T
# Out:
#              count      mean       std       min       25%       50%  \
# Support     3766.0  0.114780  0.034354  0.080773  0.093064  0.100966
# Confidence  3766.0  0.961989  0.070991  0.700000  0.956920  0.986063
# Lift        3766.0  2.458609  0.414823  1.208030  2.531111  2.610801
#
#                  75%       max
# Support     0.139596  0.378402
# Confidence  1.000000  1.000000
# Lift        2.661501  2.827783

# %%
df1.sort_values('Lift', ascending = False)
# Out:
#        Support  Confidence      Lift Recommended_Product Recommended_with  \
# 1232  0.095698    0.973214  2.827783             towels,             <---
# 356   0.086040    0.970297  2.819307             towels,             <---
# 282   0.084284    0.969697  2.817563             towels,             <---
# 243   0.083406    0.969388  2.816665             towels,             <---
# 150   0.081651    0.968750  2.814812             towels,             <---
# ...        ...         ...       ...                 ...              ...
# 2494  0.115013    0.700535  1.208953            sandwich             <---
# 3564  0.158033    0.700389  1.208702            sandwich             <---
# 1501  0.098332    0.700000  1.208030            sandwich             <---
# 2152  0.104478    0.700000  1.208030            sandwich             <---
# 2154  0.104478    0.700000  1.208030            sandwich             <---
#
#                          Recommended_Set
# ...
